# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import spacy
import pandas as pd
import ast
import matplotlib.pyplot as plt
import json


nlp = spacy.load("en_core_web_sm")

def count_tokens(txt):
  return len(nlp(txt))

def get_dataset(path_to_data):
  with open(path_to_data) as f:
    data = json.loads(f.read())
  data = [[x['description'], 1 if x['label']=='bot' else 0] for x in data]
  df = pd.DataFrame(data)
  df.columns = ["text", "labels"]
  return df

train_df = get_dataset('/content/drive/MyDrive/advNLP/twibot20/train.json')
test_explanations_df = pd.read_csv('/content/drive/MyDrive/advNLP/twibot20/test_explanations.csv', index_col=0)
test_explanations_df.weights = test_explanations_df.weights.apply(lambda x: ast.literal_eval(x))

test_explanations_df['token_count'] = test_explanations_df['text'].apply(count_tokens)
test_explanations_df['max_elem'] = test_explanations_df['weights'].apply(lambda l : max(l, key=lambda x: abs(x[1])) if len(l)>0 else ('',0))
test_explanations_df['max_elem_weight'] = test_explanations_df['weights'].apply(lambda l : abs(max(l, key=lambda x: abs(x[1]))[1]) if len(l)>0 else 0)

# %%
all_weights = [item for sublist in test_explanations_df.weights.values for item in sublist]
all_weights.sort(key=lambda x: -abs(x[1]))

# %%
for token, weight in all_weights[:10]:
  train_bot_pct = train_df[train_df.text.apply(lambda x : (token in x))].labels.mean()
  print(token, weight, train_bot_pct)
# Out:
# actor -0.814881458705768 0.4230769230769231
# Rihanna -0.7891745848179716 nan
# Comms 0.7848082280378158 0.5333333333333333
# EPM -0.7836205359652342 0.0
# Committees -0.7796661190152939 1.0
# trump 0.7664076624856749 0.7857142857142857
# player -0.7471178447017364 0.47058823529411764
# Player -0.7380681953800026 0.2413793103448276
# Jesus 0.6891305830033874 0.6382978723404256
# Host -0.6880679583576949 0.20270270270270271

# %%
train_bot_pct = train_df[train_df.text.apply(lambda x : ("Stuart" in x))].labels.mean()
print(train_bot_pct)
# Out:
# nan

# %%
misclassified_df = test_explanations_df[test_explanations_df.misclassified==True].sort_values(by='bot_prob', ascending=False)

# %%
misclassified_df.iloc[80].weights
# Out:
# [('aspiring', 0.17220007641469315),
#  ('author', -0.14323704145736627),
#  ('Liz', -0.10643629563713967),
#  ('her', 0.10518998474824658),
#  ('they', 0.09534336933253146),
#  ('editor', -0.09226288870194117)]

# %%
for idx in range(30):
  print(misclassified_df.iloc[idx].text, misclassified_df.iloc[idx].bot_prob, misclassified_df.iloc[idx].weights)
# Out:
# Embattled MYsElf for the Worst Very Common to me And you Should also Comply ...Ain't it ???  0.993384607321672 [('Comply', 0.0992785356634549), ('MYsElf', 0.0646187571067114), ('also', 0.05748827598824706), ('Common', 0.0492908101038694), ('Very', 0.037458311374991136), ('Should', 0.03431343454132944)]
# Fishing Guide at Big Bite Charters. From the Nature Coast, FL to Lake Lanier, GA.  0.9932941520716714 [('Charters', 0.008091374453649007), ('Fishing', 0.006523069974851756), ('Nature', 0.00648039698969954), ('Guide', 0.006399240508921272), ('Coast', 0.005614362963105646), ('Lake', 0.004863703314708101)]
# All opinions expressed here are stolen. AFM Local 174-496  0.9883127420043056 [('Local', 0.23297525660161286), ('AFM', -0.08462639690078476), ('174', -0.06389209824080788), ('are', 0.0432809471009209), ('stolen', 0.039892094739913175), ('496', -0.027973571954678655)]
# @MCFCrayon,@scottrobertsx,@hungry_haller @MCFCCAM_  @Bernardo_szn @GioLoCelsoSzn @ElimadAidan are top shaggers, I'm the creator of barney fc  0.9876400801786768 [('shaggers', 0.25329373508060443), ('barney', 0.11761872995275502), ('creator', 0.11596543988824057), ('I', 0.06824752965700086), ('are', 0.052534965339707355), ('fc', 0.04391862224929127)]
# Vegan. Feminist. A.R.T. Cats & pigs. 🐷🐱 RIP my angels 💜  0.9872034825984896 [('pigs', 0.08966544047009917), ('Vegan', 0.07358215382265045), ('Cats', 0.061053277218812096), ('my', -0.0422612188902813), ('RIP', 0.021727260383986757), ('Feminist', 0.01812438083851988)]
# Share with us your #SeabrookLove!  Official Twitter Feed for the City of Seabrook, Texas and is a limited public forum.  0.9871044125256008 [('SeabrookLove', 0.08588017792300878), ('Seabrook', 0.07131840268650302), ('Texas', 0.07048338962194661), ('Official', -0.06002759386851567), ('Share', 0.03919444073420807), ('of', 0.02939744361704803)]
# ♍️• LLA💙• #justiceforbreonnataylor  0.9866491489872552 [('justiceforbreonnataylor', 0.47252260085878545), ('LLA', -0.26267633714009536)]
# Project Director@ Garden of Hope Children's Ministry Uganda. Journalist Marketeer PM @ Disability Awareness Uganda. +256778342793 What'sApp/ Call me and we talk  0.985772953896821 [('Uganda', 0.26171293186202904), ('PM', -0.19211890518057445), ('Marketeer', 0.16166189742624368), ('Project', 0.1299972160816972), ('Ministry', -0.11425890552098159), ('Awareness', 0.08894088066971967)]
# Designer 🌷 Student @Udusok🎓 Music 🎵🎤 Football ⚽Lover 💘  0.9848983492042196 [('Student', 0.4201341853681442), ('Football', 0.27775963855480035), ('Lover', 0.2676344920986505), ('Designer', 0.15381676131292354), ('Music', 0.09455267920500594), ('Udusok', 0.036514330311639066)]
# Stamp collecting, SF, Horror, ONJ fan  0.9846936454393052 [('fan', 0.17221472883867653), ('Stamp', 0.14245346558294283), ('collecting', 0.08263202879588424), ('ONJ', -0.08023631297058226), ('Horror', -0.06868282393690683), ('SF', -0.05466413800139616)]
# Sr. Advisor - @realdonaldtrump 2020 🇺🇸  0.9835654260360728 [('2020', 0.51159600335885), ('Advisor', 0.2223365824162776), ('Sr', 0.2157666052748966), ('realdonaldtrump', 0.10999946330054873)]

# %%
for idx in range(20):
  print(misclassified_df.iloc[-1 - idx].text, misclassified_df.iloc[-1 - idx].bot_prob,  misclassified_df.iloc[-1 - idx].weights)
# Out:
# Spokesperson in the @DNCWarRoom | @hay_rach is my forever best friend. These tweets are my own. he/him/his  0.0066669319312806 [('Spokesperson', -0.6117393689327363), ('in', -0.10760933942520329), ('the', -0.0729043440153854), ('is', 0.051017809375973826), ('friend', -0.03150676734592848), ('his', -0.027144475608207094)]
# Stories from the sidelines. Your guide to #UCLA sports from the @dailybruin Sports section.  0.007232763803479 [('UCLA', -0.027384362528522336), ('from', -0.024853495164572515), ('Stories', -0.018452423218349806), ('sports', -0.016214452672731035), ('sidelines', -0.014196990337893586), ('the', -0.013442916666093487)]
# New Jersey reporter for @nytimes. tracey.tully@nytimes.com  0.0074030140888726 [('com', -0.21734626242104968), ('reporter', -0.20980004399444488), ('Jersey', -0.061628528764579034), ('tully', 0.061075916078974286), ('for', -0.044040909257139986), ('New', 0.03116220469294539)]
# Arkansas State assistant QB coach #family UNC-Chapel Hill alum  0.0074896248988083 [('UNC', -0.1360985628435868), ('Arkansas', -0.10997324561366517), ('QB', -0.08502584725324237), ('assistant', -0.052984705210931224), ('coach', -0.0356441119581796), ('State', -0.033359425152383305)]
# Fashion Stylist : London : Instagram Accounts: @buffalo69 #buffalo69 #kashmirwala  0.0079226280490644 [('buffalo69', -0.045419631542145955), ('Fashion', -0.03633002619778904), ('Instagram', -0.036288844894935814), ('Stylist', -0.03496866261815484), ('kashmirwala', -0.030768395940856376), ('London', -0.007327271700911826)]
# Vice Chairman & CEO at Republicans Overseas, RNC Member since 2000, Co-founder of RNC Republican National Conservative Caucus & Conservative Steering Committee  0.0085608921419353 [('Committee', -0.14458470797944883), ('RNC', -0.090867599169163), ('Caucus', -0.06578057332871878), ('Chairman', -0.05099300230075674), ('founder', -0.04692604428905204), ('since', -0.04684611911346455)]
# Home of Star Wars on @ESL - the world's largest esports company! https://t.co/lcivIs8bJ6  0.0085774854137119 [('company', -0.1417966541486562), ('on', -0.12531019889855657), ('world', -0.10464690007731936), ('the', -0.08604045864515854), ('of', -0.0711436402249479), ('largest', -0.06543746761061803)]
# The official Twitter account of the Manhattan College track & field/cross country teams. 1973 NCAA Indoor Champions. 20 Olympians.  0.0088473550829303 [('NCAA', -0.17678747405607903), ('Olympians', -0.1513348442972912), ('official', -0.07828740897031031), ('of', -0.06684777016442012), ('country', -0.06611275922765542), ('track', -0.05960454489781507)]
# Just a regular newspaper. Support WWN and subscribe for bonus content here: https://t.co/CrfWWRcHHd  0.0096897166745634 [('content', -0.048810293622885116), ('newspaper', -0.04203541332952959), ('here', -0.03532457251498715), ('bonus', -0.03428862164648213), ('regular', -0.03107641535341029), ('WWN', -0.02451278360618595)]
# Hearthstone player for @ATKmode  0.009783876017655 [('player', -0.7471178447017364), ('Hearthstone', 0.12530908219374573), ('ATKmode', 0.026031995858480043), ('for', 0.0013033709773935056)]
# Im a man child on Twitch  https://t.co/dQMkxJg5cr  Business: mizkif@getader.com  0.0102090543188082 [('mizkif', -0.24520787353134055), ('com', -0.2435928780072973), ('Twitch', 0.1925315161331336), ('Im', 0.11572749856904753), ('getader', -0.07202129967589137), ('on', 0.05419753218951909)]
# Member Secretary, Central Pollution Control Board  0.01077672605008 [('Secretary', -0.08756403071249752), ('Control', -0.07400375216951596), ('Board', -0.06610838909509348), ('Member', -0.06516029383463529), ('Pollution', -0.02678326228428898), ('Central', -0.021225967860650896)]
# I love to find the secrets buried in a pile of numbers. 4 brothers, 4 sisters, 2 sons, 1 wife. Real estate agent. Former: hitchhiker, ag econ, US Embassy Paris.  0.0113536559617338 [('Embassy', -0.22821745061273935), ('hitchhiker', -0.12009406146027887), ('agent', -0.10284071625020948), ('estate', 0.06200276153653659), ('Paris', -0.059936372178311846), ('secrets', -0.05445050007125847)]
# "Injustice anywhere is a threat to justice everywhere,” love is love, 🏳️‍🌈#BlackLivesMatter, no human is illegal, and science is real. Team @LaurenUnderwood  0.0115081490643034 [('BlackLivesMatter', -0.4389568897100078), ('justice', -0.24269283042970713), ('Injustice', -0.2021225701480091), ('and', -0.13587007350013366), ('human', -0.12260140513395001), ('Team', -0.12180736272482366)]
# Never Say Never(NSN) Somewhere Over The Rainbow.  0.0118005970451362 [('NSN', -0.11566827397858055), ('Never', -0.07973812747162617), ('Say', -0.06376481018703531), ('Over', -0.04682642314572343), ('Rainbow', -0.03662527884144501), ('The', -0.014671934806501185)]
# Sports, wrestling, & pop culture fan, host of @savedbtpod and @thejzflairshow  0.0120073505476338 [('host', -0.3688355839867892), ('pop', -0.2879698521508674), ('culture', 0.1987098299337776), ('and', -0.04154359797284016), ('fan', -0.027101047118227816), ('wrestling', -0.01843920944179117)]
# Worshiper of Jesus, apprentice of his way, member of his church, pastoring a local outpost of his kingdom @CrossWayMKE.  0.0123361004208697 [('of', -0.2552204906466544), ('pastoring', -0.20377285156811503), ('church', -0.12588710692302588), ('Worshiper', -0.1175428982302794), ('his', -0.1034763305127418), ('member', -0.09518278333774717)]
# La página en español del @catoinstitute.  0.0124796997453278 [('La', -0.010252973844485305), ('del', -0.009771196902313838), ('en', -0.009654550917802963), ('español', -0.009049679041942732), ('catoinstitute', 0.0019750264860229094), ('página', -0.0009381808837746266)]
# Child of God, Husband to @MrsAngelPrice, Father, Pastor,Teacher, Writer & all-around Geek. @matrixoftruth  0.012576348276879 [('Pastor', -0.1255704754051914), ('Husband', -0.07431415426790185), ('Father', -0.07295664562964964), ('Writer', -0.06287421052280176), ('Child', -0.045814363186874936), ('around', -0.04089727576911767)]
# Sportswriter, @NYPostSports. SNY contributor. BU alum. Tyler's & Hayley's dad. "The Big 50: NYY." https://t.co/tXNM03FCcH  0.0127965174015104 [('Sportswriter', -0.03605376545902674), ('dad', -0.02977971367022334), ('alum', -0.020881677642844584), ('SNY', -0.019516923653273278), ('Hayley', -0.015523870946442645), ('Big', -0.015073844337242973)]
